# %%
import pandas as pd
import numpy as np

# %%
netflix = pd.read_csv(r"C:\Users\thakr\Downloads\Project number 1.csv")

# %%
np.mean(netflix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.mean(netflix)
#
# File ~\miniconda3\Lib\site-packages\numpy\_core\fromnumeric.py:3594, in mean(a, axis, dtype, out, keepdims, where)
#    3592         pass
#    3593     else:
# -> 3594         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3596 return _methods._mean(a, axis=axis, dtype=dtype,
#    3597                       out=out, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# ...

# %%
print(netflix.dtypes)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
numeric_data =netflix.select_dtypes(include=['number'])

# %%
mean=numeric_data.mean()

# %%
print(mean)
# Out:
# release_year    2014.183163
# dtype: float64

# %%
numeric_data =netflix.select_dtypes(include=['number'])

# %%
variance = numeric_data.var()

# %%
print(variance)
# Out:
# release_year    77.888851
# dtype: float64

# %%
numeric_data = netflix.select_dtypes(include='number')

# %%
skewness = numeric_data.skew()
print(skewness)
# Out:
# release_year   -3.446512
# dtype: float64

# %%
numeric_data = netflix.select_dtypes(include='number')

# %%
kurt = numeric_data.kurt()
print(kurt)
# Out:
# release_year    16.219759
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = netflix.select_dtypes(include='number')

# %%
numeric_data.hist(figsize=(10,8))
plt.show()

# %%
netflix['type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
sns.boxplot(data=numeric_data)
plt.title("Box Plot")
plt.show()

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
netflix.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
duplicate=netflix.duplicated()

# %%
duplicate
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8785    False
# 8786    False
# 8787    False
# 8788    False
# 8789    False
# Length: 8790, dtype: bool

# %%
sum(duplicate)
# Out:
# 0

# %%
netflix.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 import seaborn as sns
# ----> 3 sns.boxplot(x=netflix[numeric_value])
#       4 plt.show()
#
# NameError: name 'numeric_value' is not defined

# %%
sns.boxplot(x=netflix['release_year'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 sns.boxplot(x=netflix['release_year'])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
Q1 = netflix['release_year'].quantile(0.25)
Q3 = netflix['release_year'].quantile(0.75)

IQR = Q3-Q1

# %%
lower = Q1-1.5*IQR
outliers = netflix[(netflix['release_year']<lower)]
print(outliers)
# Out:
#      show_id     type                                title          director  \
# 4         s8    Movie                              Sankofa      Haile Gerima
# 29       s25    Movie                                Jeans        S. Shankar
# 51       s27    Movie                       Minsara Kanavu       Rajiv Menon
# 53       s23    Movie                      Avvai Shanmughi    K.S. Ravikumar
# 60       s42    Movie                                 Jaws  Steven Spielberg
# ...      ...      ...                                  ...               ...
# 8702   s8232    Movie                             The Bund         Not Given
# 8743   s8524  TV Show    The Super Mario Bros. Super Show!         Not Given
# 8746   s8542  TV Show  The Twilight Zone (Original Series)         Not Given
# 8761   s8645  TV Show                           Twin Peaks         Not Given
# 8765   s8670  TV Show                        V.R. Troopers         Not Given
#
# ...

# %%
median=netflix['release_date'].median()
netflix.loc[netflix['release_date']<lower, 'release_date']=median
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'release_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 median=netflix['release_date'].median()
# ...

# %%
print(netflix.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
median=netflix['release_year'].median()
netflix.loc[netflix['release_year']<lower, 'release_year']=median

# %%
import matplotlib.pyplot as plt
sns.boxplot(x=netflix['release_year'])
plt.show()

# %%
netflix.hist(figsize=(10,8))
plt.show()
